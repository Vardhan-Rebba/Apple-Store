# %% [markdown]
# <a href="https://colab.research.google.com/github/Vardhan-Rebba/Apple-Store/blob/master/drug%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
drug=pd.read_csv("/content/drive/MyDrive/Classroom/Datasets/new/Drug_overdose_death_rates__by_drug_type__sex__age__race__and_Hispanic_origin__United_States.csv")
drug
# Out:
#                       INDICATOR                                  PANEL  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
drug.columns
# Out:
# Index(['INDICATOR', 'PANEL', 'PANEL_NUM', 'UNIT', 'UNIT_NUM', 'STUB_NAME',
#        'STUB_NAME_NUM', 'STUB_LABEL', 'STUB_LABEL_NUM', 'YEAR', 'YEAR_NUM',
#        'AGE', 'AGE_NUM', 'ESTIMATE', 'FLAG'],
#       dtype='object')

# %%
drug.describe()
# Out:
#          PANEL_NUM     UNIT_NUM  STUB_NAME_NUM  STUB_LABEL_NUM         YEAR  \
# count  6228.000000  6228.000000    6228.000000     6228.000000  6228.000000
# mean      2.500000     1.578035       3.028902        3.383006  2008.664740
# std       1.707962     0.493913       1.447036        1.526819     5.849512
# min       0.000000     1.000000       0.000000        0.100000  1999.000000
# 25%       1.000000     1.000000       2.000000        2.100000  2004.000000
# 50%       2.500000     2.000000       3.000000        3.220000  2009.000000
# 75%       4.000000     2.000000       4.000000        4.600000  2014.000000
# max       5.000000     2.000000       5.000000        5.930000  2018.000000
#
#           YEAR_NUM      AGE_NUM     ESTIMATE
# count  6228.000000  6228.000000  5117.000000
# mean     10.664740     1.354913     4.743443
# std       5.849512     0.301459     6.424471
# min       1.000000     1.100000     0.000000
# 25%       6.000000     1.100000     0.800000
# ...

# %%
drug.describe()
# Out:
#          PANEL_NUM     UNIT_NUM  STUB_NAME_NUM  STUB_LABEL_NUM         YEAR  \
# count  6228.000000  6228.000000    6228.000000     6228.000000  6228.000000
# mean      2.500000     1.578035       3.028902        3.383006  2008.664740
# std       1.707962     0.493913       1.447036        1.526819     5.849512
# min       0.000000     1.000000       0.000000        0.100000  1999.000000
# 25%       1.000000     1.000000       2.000000        2.100000  2004.000000
# 50%       2.500000     2.000000       3.000000        3.220000  2009.000000
# 75%       4.000000     2.000000       4.000000        4.600000  2014.000000
# max       5.000000     2.000000       5.000000        5.930000  2018.000000
#
#           YEAR_NUM      AGE_NUM     ESTIMATE
# count  6228.000000  6228.000000  5117.000000
# mean     10.664740     1.354913     4.743443
# std       5.849512     0.301459     6.424471
# min       1.000000     1.100000     0.000000
# 25%       6.000000     1.100000     0.800000
# ...

# %%
drugs=drug.rename(columns={'PANEL':'CAUSE OF DEATH'})
drugs
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
drugs['AGE'].unique()
# Out:
# array(['All ages', 'Under 15 years', '15-24 years', '25-34 years',
#        '35-44 years', '45-54 years', '55-64 years', '65-74 years',
#        '75-84 years', '85 years and over'], dtype=object)

# %%
drug1=drugs.replace(to_replace='Under 15 years', value='13-14 years')
drug1
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
drug0=drug1.replace(to_replace='All ages',value='10-12 years')
drug0
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
drug0.AGE.unique()
# Out:
# array(['10-12 years', '13-14 years', '15-24 years', '25-34 years',
#        '35-44 years', '45-54 years', '55-64 years', '65-74 years',
#        '75-84 years', '85 years and over'], dtype=object)

# %%
drug0.AGE.value_counts()
# Out:
# AGE
# 10-12 years          2988
# 13-14 years           360
# 15-24 years           360
# 25-34 years           360
# 35-44 years           360
# 45-54 years           360
# 55-64 years           360
# 65-74 years           360
# 75-84 years           360
# 85 years and over     360
# Name: count, dtype: int64

# %%
drug0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6228 entries, 0 to 6227
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDICATOR       6228 non-null   object
#  1   CAUSE OF DEATH  6228 non-null   object
#  2   PANEL_NUM       6228 non-null   int64
#  3   UNIT            6228 non-null   object
#  4   UNIT_NUM        6228 non-null   int64
#  5   STUB_NAME       6228 non-null   object
#  6   STUB_NAME_NUM   6228 non-null   int64
#  7   STUB_LABEL      6228 non-null   object
#  8   STUB_LABEL_NUM  6228 non-null   float64
#  9   YEAR            6228 non-null   int64
#  10  YEAR_NUM        6228 non-null   int64
#  11  AGE             6228 non-null   object
#  12  AGE_NUM         6228 non-null   float64
#  13  ESTIMATE        5117 non-null   float64
#  14  FLAG            1111 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 730.0+ KB

# %%
drug2=drug0.rename(columns={'STUB_LABEL': 'GENDER'})
drug2
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
drug2.GENDER.value_counts()
# Out:
# GENDER
# All persons                                                                  240
# Female                                                                       240
# Male                                                                         240
# Male: Hispanic or Latino: All races                                          126
# Female: Not Hispanic or Latino: American Indian or Alaska Native             126
# Female: Not Hispanic or Latino: Black                                        126
# Female: Not Hispanic or Latino: White                                        126
# Male: Not Hispanic or Latino: American Indian or Alaska Native               126
# Male: Not Hispanic or Latino: Black                                          126
# Male: Not Hispanic or Latino: White                                          126
# Female: Hispanic or Latino: All races                                        126
# ...

# %%
drug2.isnull()
# Out:
#       INDICATOR  CAUSE OF DEATH  PANEL_NUM   UNIT  UNIT_NUM  STUB_NAME  \
# 0         False           False      False  False     False      False
# 1         False           False      False  False     False      False
# 2         False           False      False  False     False      False
# 3         False           False      False  False     False      False
# 4         False           False      False  False     False      False
# ...         ...             ...        ...    ...       ...        ...
# 6223      False           False      False  False     False      False
# 6224      False           False      False  False     False      False
# 6225      False           False      False  False     False      False
# 6226      False           False      False  False     False      False
# 6227      False           False      False  False     False      False
#
#       STUB_NAME_NUM  GENDER  STUB_LABEL_NUM   YEAR  YEAR_NUM    AGE  AGE_NUM  \
# ...

# %%
drug2.fillna(method='ffill')
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
del drug2['FLAG']

# %%
drug2
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
gender=drug2.groupby('GENDER')
gender.first()
# Out:
#                                                                     INDICATOR  \
# GENDER
# 13-14 years                                         Drug overdose death rates
# 15-24 years                                         Drug overdose death rates
# 25-34 years                                         Drug overdose death rates
# 35-44 years                                         Drug overdose death rates
# 45-54 years                                         Drug overdose death rates
# 55-64 years                                         Drug overdose death rates
# 65-74 years                                         Drug overdose death rates
# 75-84 years                                         Drug overdose death rates
# 85 years and over                                   Drug overdose death rates
# All persons                                         Drug overdose death rates
# Female                                              Drug overdose death rates
# ...

# %%
male=gender.get_group('Male')
male
# Out:
#                       INDICATOR  \
# 19    Drug overdose death rates
# 20    Drug overdose death rates
# 21    Drug overdose death rates
# 22    Drug overdose death rates
# 23    Drug overdose death rates
# ...                         ...
# 6106  Drug overdose death rates
# 6127  Drug overdose death rates
# 6157  Drug overdose death rates
# 6178  Drug overdose death rates
# 6208  Drug overdose death rates
#
#                                          CAUSE OF DEATH  PANEL_NUM  \
# 19                             All drug overdose deaths          0
# 20                             All drug overdose deaths          0
# 21                             All drug overdose deaths          0
# 22                             All drug overdose deaths          0
# 23                             All drug overdose deaths          0
# ...                                                 ...        ...
# 6106           Drug overdose deaths involving methadone          3
# ...

# %%
female=gender.get_group('Female')
female
# Out:
#                       INDICATOR  \
# 39    Drug overdose death rates
# 40    Drug overdose death rates
# 41    Drug overdose death rates
# 42    Drug overdose death rates
# 43    Drug overdose death rates
# ...                         ...
# 6107  Drug overdose death rates
# 6128  Drug overdose death rates
# 6158  Drug overdose death rates
# 6179  Drug overdose death rates
# 6209  Drug overdose death rates
#
#                                          CAUSE OF DEATH  PANEL_NUM  \
# 39                             All drug overdose deaths          0
# 40                             All drug overdose deaths          0
# 41                             All drug overdose deaths          0
# 42                             All drug overdose deaths          0
# 43                             All drug overdose deaths          0
# ...                                                 ...        ...
# 6107           Drug overdose deaths involving methadone          3
# ...

# %%
male['YEAR'].value_counts()
# Out:
# YEAR
# 1999    12
# 2000    12
# 2016    12
# 2015    12
# 2014    12
# 2013    12
# 2017    12
# 2012    12
# 2011    12
# 2010    12
# 2009    12
# 2008    12
# 2007    12
# 2006    12
# 2005    12
# 2004    12
# 2003    12
# 2002    12
# 2001    12
# 2018    12
# Name: count, dtype: int64

# %%
female['YEAR'].value_counts()
# Out:
# YEAR
# 1999    12
# 2000    12
# 2017    12
# 2016    12
# 2015    12
# 2014    12
# 2013    12
# 2012    12
# 2011    12
# 2010    12
# 2009    12
# 2008    12
# 2007    12
# 2006    12
# 2005    12
# 2004    12
# 2003    12
# 2002    12
# 2001    12
# 2018    12
# Name: count, dtype: int64

# %%
male_w=gender.get_group('Male: White')
male_w
# Out:
#                       INDICATOR  \
# 58    Drug overdose death rates
# 59    Drug overdose death rates
# 60    Drug overdose death rates
# 61    Drug overdose death rates
# 62    Drug overdose death rates
# ...                         ...
# 5976  Drug overdose death rates
# 6027  Drug overdose death rates
# 6078  Drug overdose death rates
# 6129  Drug overdose death rates
# 6180  Drug overdose death rates
#
#                                          CAUSE OF DEATH  PANEL_NUM  \
# 58                             All drug overdose deaths          0
# 59                             All drug overdose deaths          0
# 60                             All drug overdose deaths          0
# 61                             All drug overdose deaths          0
# 62                             All drug overdose deaths          0
# ...                                                 ...        ...
# 5976          Drug overdose deaths involving any opioid          1
# ...

# %%
female_w=gender.get_group('Female: White')
female_w
# Out:
#                       INDICATOR  \
# 138   Drug overdose death rates
# 139   Drug overdose death rates
# 140   Drug overdose death rates
# 141   Drug overdose death rates
# 142   Drug overdose death rates
# ...                         ...
# 5979  Drug overdose death rates
# 6030  Drug overdose death rates
# 6081  Drug overdose death rates
# 6132  Drug overdose death rates
# 6183  Drug overdose death rates
#
#                                          CAUSE OF DEATH  PANEL_NUM  \
# 138                            All drug overdose deaths          0
# 139                            All drug overdose deaths          0
# 140                            All drug overdose deaths          0
# 141                            All drug overdose deaths          0
# 142                            All drug overdose deaths          0
# ...                                                 ...        ...
# 5979          Drug overdose deaths involving any opioid          1
# ...

# %%
drug2['YEAR'].min()
# Out:
# 1999

# %%
drug2['YEAR'].value_counts()
# Out:
# YEAR
# 2018    414
# 2000    306
# 2017    306
# 2016    306
# 2015    306
# 2014    306
# 2013    306
# 2012    306
# 2011    306
# 2010    306
# 1999    306
# 2008    306
# 2007    306
# 2006    306
# 2005    306
# 2004    306
# 2003    306
# 2002    306
# 2001    306
# 2009    306
# Name: count, dtype: int64

# %%
drug2['CAUSE OF DEATH'].value_counts()
# Out:
# CAUSE OF DEATH
# All drug overdose deaths                                                         1038
# Drug overdose deaths involving any opioid                                        1038
# Drug overdose deaths involving natural and semisynthetic opioids                 1038
# Drug overdose deaths involving methadone                                         1038
# Drug overdose deaths involving other synthetic opioids (other than methadone)    1038
# Drug overdose deaths involving heroin                                            1038
# Name: count, dtype: int64

# %%
drug_name=drug2.groupby('CAUSE OF DEATH')
drug_name.first()
# Out:
#                                                                     INDICATOR  \
# CAUSE OF DEATH
# All drug overdose deaths                            Drug overdose death rates
# Drug overdose deaths involving any opioid           Drug overdose death rates
# Drug overdose deaths involving heroin               Drug overdose death rates
# Drug overdose deaths involving methadone            Drug overdose death rates
# Drug overdose deaths involving natural and semi...  Drug overdose death rates
# Drug overdose deaths involving other synthetic ...  Drug overdose death rates
#
#                                                     PANEL_NUM  \
# CAUSE OF DEATH
# All drug overdose deaths                                    0
# Drug overdose deaths involving any opioid                   1
# Drug overdose deaths involving heroin                       5
# Drug overdose deaths involving methadone                    3
# Drug overdose deaths involving natural and semi...          2
# ...

# %%
opioid=drug_name.get_group('Drug overdose deaths involving any opioid')
opioid
# Out:
#                       INDICATOR                             CAUSE OF DEATH  \
# 987   Drug overdose death rates  Drug overdose deaths involving any opioid
# 988   Drug overdose death rates  Drug overdose deaths involving any opioid
# 989   Drug overdose death rates  Drug overdose deaths involving any opioid
# 990   Drug overdose death rates  Drug overdose deaths involving any opioid
# 991   Drug overdose death rates  Drug overdose deaths involving any opioid
# ...                         ...                                        ...
# 6019  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6020  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6021  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6022  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6023  Drug overdose death rates  Drug overdose deaths involving any opioid
#
# ...

# %%
opioid['AGE'].value_counts()
# Out:
# AGE
# 10-12 years          498
# 13-14 years           60
# 15-24 years           60
# 25-34 years           60
# 35-44 years           60
# 45-54 years           60
# 55-64 years           60
# 65-74 years           60
# 75-84 years           60
# 85 years and over     60
# Name: count, dtype: int64

# %%
heroin=drug_name.get_group('Drug overdose deaths involving heroin')
heroin
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 3989  Drug overdose death rates  Drug overdose deaths involving heroin
# 4448  Drug overdose death rates  Drug overdose deaths involving heroin
# 4476  Drug overdose death rates  Drug overdose deaths involving heroin
# 4504  Drug overdose death rates  Drug overdose deaths involving heroin
# 4532  Drug overdose death rates  Drug overdose deaths involving heroin
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
heroin['AGE'].value_counts()
# Out:
# AGE
# 10-12 years          498
# 13-14 years           60
# 15-24 years           60
# 25-34 years           60
# 35-44 years           60
# 45-54 years           60
# 55-64 years           60
# 65-74 years           60
# 75-84 years           60
# 85 years and over     60
# Name: count, dtype: int64

# %%
male_w['CAUSE OF DEATH'].value_counts()
# Out:
# CAUSE OF DEATH
# All drug overdose deaths                                                         21
# Drug overdose deaths involving any opioid                                        21
# Drug overdose deaths involving natural and semisynthetic opioids                 21
# Drug overdose deaths involving methadone                                         21
# Drug overdose deaths involving other synthetic opioids (other than methadone)    21
# Drug overdose deaths involving heroin                                            21
# Name: count, dtype: int64

# %%
drug_name['YEAR'].value_counts()
# Out:
# CAUSE OF DEATH                                                                 YEAR
# All drug overdose deaths                                                       2018    69
#                                                                                1999    51
#                                                                                2014    51
#                                                                                2017    51
#                                                                                2016    51
#                                                                                        ..
# Drug overdose deaths involving other synthetic opioids (other than methadone)  2003    51
#                                                                                2002    51
#                                                                                2001    51
# ...

# %%
drug3=drug2.rename(columns={'YEAR_NUM':'NUMBER OF DEATHS PER YEAR'})
drug3
# Out:
#                       INDICATOR                         CAUSE OF DEATH  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
drug3.plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # ***GRAPHS***

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
drug2.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
drug3['NUMBER OF DEATHS PER YEAR'].plot.bar(stacked=True, color='red')
# Out:
# <Axes: >

# %%
color={
    "boxes":"Green",
    "whiskers":"Purple",
    "medians":"DarkBlue",
    "caps":"Red"
}

# %%
drug3['NUMBER OF DEATHS PER YEAR'].plot(color=color,kind='box')
# Out:
# <Axes: >

# %%
drug3.plot.area()
# Out:
# <Axes: >

# %%
drug3[['YEAR','NUMBER OF DEATHS PER YEAR']].plot(x='YEAR',y='NUMBER OF DEATHS PER YEAR',kind='scatter')
# Out:
# <Axes: xlabel='YEAR', ylabel='NUMBER OF DEATHS PER YEAR'>
